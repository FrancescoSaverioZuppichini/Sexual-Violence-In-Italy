# %% [markdown]
# # Rapes in Italy
#
#
# Little analysis using official [INSTAT data](http://dati.istat.it/Index.aspx?DataSetCode=DCCV_AUTVITTPS) on sexual violence showing that regular foreigners are 7.5 times more like to commit sexual violence
#
# Let's start by opening the INSTAT data

# %%
import pandas as pd

df = pd.read_csv('./DCCV_AUTVITTPS_02022021182031375.csv', index_col=0)

# %% [markdown]
# Let's check the crimes types

# %%
df['Tipo di delitto'].unique()
# Out:
# array(['strage', 'omicidi volontari consumati',
#        'omicidi volontari consumati a scopo di furto o rapina',
#        'omicidi volontari consumati di tipo mafioso',
#        'omicidi volontari consumati a scopo terroristico',
#        'tentati omicidi', 'infanticidi', 'omicidi preterintenzionali',
#        'omicidi colposi', 'omicidi colposi da incidente stradale',
#        'percosse', 'lesioni dolose', 'minacce', 'stalking',
#        'sequestri di persona', 'violenze sessuali',
#        'atti sessuali con minorenne', 'corruzione di minorenne',
#        'sfruttamento e favoreggiamento della prostituzione',
#        'pornografia minorile e detenzione di materiale pedopornografico',
#        'furti', 'furti con strappo', 'furti con destrezza',
#        'furti in abitazioni', 'furti in esercizi commerciali',
#        'furti in auto in sosta',
#        "furti di opere d'arte e materiale archeologico",
#        'furti di automezzi pesanti trasportanti merci',
#        'furti di ciclomotori', 'furti di motocicli',
#        'furti di autovetture', 'rapine', 'rapine in abitazione',
#        'rapine in banca', 'rapine in uffici postali',
#        'rapine in esercizi commerciali', 'rapine in pubblica via',
#        'estorsioni', 'truffe e frodi informatiche', 'delitti informatici',
#        'contraffazione di marchi e prodotti industriali',
#        'violazione della proprietà intellettuale', 'ricettazione',
#        'riciclaggio e impiego di denaro, beni o utilità di provenienza illecita',
#        'usura', 'danneggiamenti', 'incendi', 'incendi boschivi',
#        'danneggiamento seguito da incendio',
#        'normativa sugli stupefacenti', 'attentati',
#        'associazione per delinquere', 'associazione di tipo mafioso',
#        'contrabbando', 'altri delitti', 'totale'], dtype=object)

# %% [markdown]
# ## Rapes %
#
# Okay, now we have find out the correct ratio for sexual violence between italians and foreigners

# %%
df_rape = df[(df['Tipo di delitto'] == 'violenze sessuali') & (df['TIPO_DATO35'] == 'OFFEND')]

rapes_it = df_rape[df_rape['Cittadinanza'] == 'italiano-a']['Value'].sum()

rapes_fo = df_rape[df_rape['Cittadinanza'] == 'straniero-a']['Value'].sum()

rapes_tot = df_rape[df_rape['Cittadinanza'] == 'totale']['Value'].sum()

rapes_it, rapes_fo, rapes_tot

f'Rapes it = {rapes_it / rapes_tot:.2f}%, rapes foreigner = {rapes_fo / rapes_tot:.2f}%'
# Out:
# 'Rapes it = 0.58%, rapes foreigner = 0.42%'

# %% [markdown]
# ### Normalize per population

# %%
tot_pop = 60360000
pop_fo = 5255503
pop_it = tot_pop - pop_fo

pop_it_per = pop_it / tot_pop 
pop_pop_per = pop_fo / tot_pop 

rapes_it_per = rapes_it / rapes_tot
rapes_fo_per = rapes_fo / rapes_tot

# compute ratio rape/person for italians
rapes_ratio_it = rapes_it_per / pop_it_per 

# compute ratio rape/person for foreigners
rapes_ratio_fo = rapes_fo_per / pop_pop_per

rapes_ratio_it, rapes_ratio_fo

f'Foreigners rapes {rapes_ratio_fo / rapes_ratio_it:.2f} times more than Italian'
# Out:
# 'Foreigners rapes 7.50 times more than Italian'

# %%
df_rape
# Out:
#          Territorio TIPO_DATO35  \
# ITTER107
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
# IT           Italia      OFFEND
#
#                                                   Tipo dato REATI_PS  \
# ITTER107
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
# IT        numero di autori di delitto denunciati/arresta...     RAPE
#
#             Tipo di delitto  SEXISTAT1    Sesso    ETA1   Classe di età  \
# ITTER107
# IT        violenze sessuali          1   maschi  Y18-24      18-24 anni
# IT        violenze sessuali          2  femmine  Y18-24      18-24 anni
# IT        violenze sessuali          1   maschi  Y25-34      25-34 anni
# IT        violenze sessuali          2  femmine  Y25-34      25-34 anni
# IT        violenze sessuali          1   maschi  Y35-44      35-44 anni
# IT        violenze sessuali          2  femmine  Y35-44      35-44 anni
# IT        violenze sessuali          1   maschi  Y45-54      45-54 anni
# IT        violenze sessuali          2  femmine  Y45-54      45-54 anni
# IT        violenze sessuali          1   maschi  Y55-64      55-64 anni
# IT        violenze sessuali          2  femmine  Y55-64      55-64 anni
# IT        violenze sessuali          1   maschi  Y_GE65   65 anni e più
# IT        violenze sessuali          2  femmine  Y_GE65   65 anni e più
# IT        violenze sessuali          1   maschi  Y14-17      14-17 anni
# IT        violenze sessuali          2  femmine  Y14-17      14-17 anni
# IT        violenze sessuali          1   maschi  Y_UN13  fino a 13 anni
# IT        violenze sessuali          2  femmine  Y_UN13  fino a 13 anni
# IT        violenze sessuali          1   maschi  Y18-24      18-24 anni
# IT        violenze sessuali          2  femmine  Y18-24      18-24 anni
# IT        violenze sessuali          1   maschi  Y25-34      25-34 anni
# IT        violenze sessuali          2  femmine  Y25-34      25-34 anni
# IT        violenze sessuali          1   maschi  Y35-44      35-44 anni
# IT        violenze sessuali          2  femmine  Y35-44      35-44 anni
# IT        violenze sessuali          1   maschi  Y45-54      45-54 anni
# IT        violenze sessuali          2  femmine  Y45-54      45-54 anni
# IT        violenze sessuali          2  femmine  Y55-64      55-64 anni
# IT        violenze sessuali          1   maschi  Y_GE65   65 anni e più
# IT        violenze sessuali          2  femmine  Y_GE65   65 anni e più
# IT        violenze sessuali          1   maschi  Y14-17      14-17 anni
# IT        violenze sessuali          2  femmine  Y14-17      14-17 anni
# IT        violenze sessuali          1   maschi  Y_UN13  fino a 13 anni
# IT        violenze sessuali          2  femmine  Y_UN13  fino a 13 anni
# IT        violenze sessuali          1   maschi  Y18-24      18-24 anni
# IT        violenze sessuali          2  femmine  Y18-24      18-24 anni
# IT        violenze sessuali          1   maschi  Y35-44      35-44 anni
# IT        violenze sessuali          1   maschi  Y55-64      55-64 anni
# IT        violenze sessuali          1   maschi  Y45-54      45-54 anni
# IT        violenze sessuali          2  femmine  Y35-44      35-44 anni
# IT        violenze sessuali          2  femmine  Y45-54      45-54 anni
# IT        violenze sessuali          1   maschi  Y25-34      25-34 anni
# IT        violenze sessuali          1   maschi  Y55-64      55-64 anni
# IT        violenze sessuali          2  femmine  Y25-34      25-34 anni
# IT        violenze sessuali          2  femmine  Y55-64      55-64 anni
# IT        violenze sessuali          1   maschi  Y_GE65   65 anni e più
# IT        violenze sessuali          2  femmine  Y_GE65   65 anni e più
# IT        violenze sessuali          2  femmine  Y14-17      14-17 anni
# IT        violenze sessuali          1   maschi  Y14-17      14-17 anni
# IT        violenze sessuali          1   maschi  Y_UN13  fino a 13 anni
# IT        violenze sessuali          2  femmine  Y_UN13  fino a 13 anni
#
#          CITTADINANZA Cittadinanza  TIME  Seleziona periodo  Value  \
# ITTER107
# IT                ITL   italiano-a  2019               2019    308
# IT                ITL   italiano-a  2019               2019      8
# IT                ITL   italiano-a  2019               2019    420
# IT                ITL   italiano-a  2019               2019     11
# IT                ITL   italiano-a  2019               2019    640
# IT                ITL   italiano-a  2019               2019     17
# IT                ITL   italiano-a  2019               2019    608
# IT                ITL   italiano-a  2019               2019     13
# IT                ITL   italiano-a  2019               2019    396
# IT                ITL   italiano-a  2019               2019      8
# IT                ITL   italiano-a  2019               2019    344
# IT                ITL   italiano-a  2019               2019      4
# IT                ITL   italiano-a  2019               2019    123
# IT                ITL   italiano-a  2019               2019      3
# IT                ITL   italiano-a  2019               2019     24
# IT                ITL   italiano-a  2019               2019      0
# IT                FRG  straniero-a  2019               2019    425
# IT                FRG  straniero-a  2019               2019      0
# IT                FRG  straniero-a  2019               2019    653
# IT                FRG  straniero-a  2019               2019      9
# IT                FRG  straniero-a  2019               2019    522
# IT                FRG  straniero-a  2019               2019     15
# IT                FRG  straniero-a  2019               2019    243
# IT                FRG  straniero-a  2019               2019      4
# IT                FRG  straniero-a  2019               2019      2
# IT                FRG  straniero-a  2019               2019     30
# IT                FRG  straniero-a  2019               2019      1
# IT                FRG  straniero-a  2019               2019     96
# IT                FRG  straniero-a  2019               2019      4
# IT                FRG  straniero-a  2019               2019     16
# IT                FRG  straniero-a  2019               2019      0
# IT              TOTAL       totale  2019               2019    733
# IT              TOTAL       totale  2019               2019      8
# IT              TOTAL       totale  2019               2019   1162
# IT                FRG  straniero-a  2019               2019     75
# IT              TOTAL       totale  2019               2019    851
# IT              TOTAL       totale  2019               2019     32
# IT              TOTAL       totale  2019               2019     17
# IT              TOTAL       totale  2019               2019   1073
# IT              TOTAL       totale  2019               2019    471
# IT              TOTAL       totale  2019               2019     20
# IT              TOTAL       totale  2019               2019     10
# IT              TOTAL       totale  2019               2019    374
# IT              TOTAL       totale  2019               2019      5
# IT              TOTAL       totale  2019               2019      7
# IT              TOTAL       totale  2019               2019    219
# IT              TOTAL       totale  2019               2019     40
# IT              TOTAL       totale  2019               2019      0
#
#           Flag Codes  Flags
# ITTER107
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN
# IT               NaN    NaN

# %% [markdown]
# Meaning if you are women and you want to go out, you are 7.5 less like to be sexually attacked by an Italian
